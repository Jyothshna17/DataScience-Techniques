# %% [markdown]
# Sorting Code

# %%
import random
import string
import matplotlib.pyplot as p

inp = input('Enter the String: ') 
inp1 = list(inp)

alpha = []
dig = []
spec_charact = []

for de in inp:
    if de.isalpha():
        alpha.append(de)
    elif de.isdigit():
      dig.append(de)
    else:
      spec_charact.append(de)

e=len(alpha)
f=len(dig)

for i in range(e):
    for j in range(1, e-i):
        if alpha[j-1] < alpha[j]:
            (alpha[j-1], alpha[j]) = (alpha[j], alpha[j-1])

for i in range(f):
    for j in range(1, f-i):
        if dig[j-1] < dig[j]:
            (dig[j-1], dig[j]) = (dig[j], dig[j-1])

for i in range(len(spec_charact)):
    for j in range(i + 1, len(spec_charact)):

        if spec_charact[i] > spec_charact[j]:
           spec_charact[i], spec_charact[j] = spec_charact[j], spec_charact[i]

output=''.join(dig+alpha+spec_charact)

def ran_st(size):  
        gen_st=[];
        for i in range(size):
            j=random.randrange(1,20) 
            s=''.join(random.choice(string.ascii_uppercase +string.ascii_lowercase +string.digits+string.punctuation)for n in range(j))
            gen_st.append(s)
        return gen_st  

Q=ran_st(500)

xaxis=[]
yaxis=[]

for i in range(0,len(Q)):
    xaxis.append(i)
    yaxis.append(len(Q[i]))
p.xlabel('xaxis') 
p.ylabel('yaxis') 
p.scatter(xaxis,yaxis)
p.show()

# %% [markdown]
# Test-Case 1:

# %%
# Out:
# Enter the String: ('vRUAk6RCe4 64K0N49C3C 3VcpKdAUnr Ub7yNBapbY DqabThBZkJ bAZYqzYz58 I6Qefde1v6 tOk0qFO6xc Z6CLKDNRY3 jeBu2WHsP6 qUrn4gpkvP tAM2OsXT8m ltYigWEMZd zdEtldcq08 JnDTTMzi9a PTHQ4H9PAi zZe6ie6z3e YrOQfHXTCE mA4VogHHC8 FrofYlQGw9 SykiNfRl33 h0oXeCGPEN QuFXaI2Zww uJWf9icGXl ekRLKPYquE Q5GT5vfGjn bXsryPvF5f HGN2qkpP41 093Z9YbFy7 nDPfCU5hiG VtQC1QyxTj IjmcIKYONI YFRxEEylF3 mKoVdNfb1W etnI84dPmw uAgPWuXuce oleywjrS3B 64TQeugYWn C557x6dV70 SuQWHmbojn Gifr2SEnyp vdNrtRCkkP hfl81iHOmS ph2Es8OzGJ JI2bil74pj MDUm1OumaT J8Wt7MDNy9 dl7sAw1LGF HqItnCBw3A rrV3YCa8hx wuWGpByaE E4zBCPRWD J3o1WXUcU IwtrcBwkn xr0eZkeGX UBedoS0YN lYZ4yNkyt HNnIfg3nz 6wBcWRtPs 8KGZqbdPR LuVVsXDMX jfglbGLjB DEg9wP8I8 68pqFw0jk SNUt4XVBx c1GJakfin Pe1VU4RVd ZQze8XHCQ Z24tVrsA0 S07hwbU87 Q4Qryl3YA okSxagIQE 4wx77kp9x DzeGX5KtW 9QnJHvXp2 cPoW0YcHL SKo9fQXFU GDdwJN42y ORAsNzJrr QSNovpie1 6GhTC8Wvq nNQizvBLY UdZjjxc7N oeVdRWRMV iz49L30Aa kJdaTuwUU PFDSMinME NQYEXETRz 8EarLA9KS E9MZjftsT qTPFdYfEN o6nFWsLDp HOY6j5ba
# ...

# %% [markdown]
# Test-Case 2:

# %%
# Out:
# Enter the String: ('A9FrrHSa1F qs6yVFiTPT 1fK87K56rO UAN38t3EgY nzzU0csoVH 5R7OBTvsJw akxsrRqI9T 3hQPbAAS4i nTXYCbuLGP J5S4JtTRoP MKoSHNVaMJ bXkcegBdcf i5k9vTq9if hdcCZDaDJ4 4pSAj0oMWW 84wwAApTC9 OC0W5mWq6j pDMq7Ebt3a 4IUKRAJUKk 4sZRmN19ov 8uS5r7wLks BWC1nnXcWo RG1zcg2yqB OPOUpO6LJa vJEK7KSBEG gz1n0CuBPF tmUQdzJd53 94rNikVocw bO8jUzPqGf EvxHGlhFC4 WS3aFBqR2S RjahjSbxis 8O7ULzKwac 4KxfF3FQvu yKvJ32YUwm fWjyaB7hDg vsVi3cqJfu GhyWrwwn19 rlNp9Iha70 s52vzWG2kg tuYyyBuVFJ N7vCXDaZti YmKkEPXa8X O6GNSAvN8V xeeE76S5zE lgi53T7uEO K3ka4wTlBZ SIAo3MqFLn BCzmPb0kiX 4kcF9mI5Bm RG7vjcrt wumHL88O XZOkjP3O bMx7OLEA SK4Wzg0t FJsjR42V aEMvkiLF hiYpdVgn SEtsKYRd WYyCcaaA MKpoxq85 Nv1YYioy x2xToNTj TzlsN8GG r7hG8KaC zUL7NHid xtCLN5Vi Euru0oJv I8oeC8kX oZxsdbU9 PhxxPK55 HtaLLRqY QJ0r72gL qtM5JZAa hx1Wv5kg IeVC9cKY 9rFjXqyx kAMpSzSD OThvStpq 7ebCOiSs Ve4ssw8x Ip22EFIb DlsM5Hcs NGA98jpT jm3GpJZr O2KO9JSy arA7KpXx jqaHXS5H EugfWL4p QMWcdM6j Rjk2m78N oqqlxjDj KaOPmKQF Aw4Oe2g3 kJA7k6S6 h0pAQm6s PzWJWpQa up9vL
# ...

# %% [markdown]
# Test-Case 3:

# %%
# Out:
# Enter the String: ('j  k  5  X  e  G  a  r  Y  V  1  N  2  v  y  o  t  L  R  W  B  g  d  H  J  q  z  b  O  c  M8  U0  qG  zg  ms  oV  PJ  aH  qA  Um  f3  5x  Mt  X3  rk  my  Y1  WY  vG  3x  Bz  Nj  zd  MZ  0T  KP  UG  vm  qa  Zx  8t  Vv  E8  yx  e1  lT  os  5D  U5  TL  jE  2Q  Fu  CC  j9  2B  5l  BJ  fe  Te  VxW  LvP  4aP  cR9  vpV  8aL  ZjW  8U2  8sS  ymi  h1Y  s8B  9VC  7k2  zku  jUC  Gis  crr  wFR  d51  1Gw  vO3  tVm  D2R  jzt  iFx  ZDy  Bqq  Zbw  TX7  1jL  kzl  esb  B9z  UgA  InC  Hbn  w4x  LmA  dKN  yeE  yIv  n05  axt  jDv  XIf  hJx  ZDc  Smh  RoB  soq  epo  Cis  2UX  n1Y  V3C  ajP  Hsd  6K2  UbF  Mdc  RtW  D22  C80  RDM  4dv  y5V  nix  hGh  Vcl  xby  Twp  8se  kZL  2YT  le0  2bI  QW7  BNN  st7  Vb5  zab  kdN  rjz  FIX  Dvn  qne  aGU  9fu  1Bu  AnK  dKH  DoH  tEU  EiP  ZkY  ERR  LVb  vWv  R2c  2pRQ  6nmt  FBwc  Aj3m  15jl  J5jz  Fav1  eG7u  Qh9c  43xz  9Cgm  dK0K  gu0f  ORP0  9PmZ  J1oY  O0mY  jERn  hnPW  lX5Q  5ub6  5qex  vw4k  MtOT  AYTn  SQIU  M8uM  M33X  kh2w  YaNI  nAzI  Oi
# ...

# %% [markdown]
# Test Case 4:

# %%
# Out:
# Enter the String: ['E9yhd', 'CHyxE', 'CMjlP', 'VewXZ', 'TKxqD', 'KfziS', 'pTp8I', 'utMMb', 'xUDxW', '3bYGB', 'I2xb3', 'hhmAK', '8xxTO', 'fOnKo', 'skDNP', '0wKIJ', 'ia41j', 'JMBHn', '8BuUJ', 'CLjre', 'w2ILR', 'fZ58T', 'Q7DoF', 'KDtum', 'FzKa5', 'RrHsK', 'vBSCG', 'zq5HX', '6zyrG', 'Sqgai', '1SwQq', 'KsPq2', '60lWG', 'Gj6Nl', 'ykk2D', 'FnKwM', 'UcTUQ', 'lrCX1', 'ArtyV', 'Lb04m', '9hSkG', 'W27ux', 'gU01f', 'Ng4qv', 'WYgfq', 'O3IGB', '2Klqt', 'YoAn2', 'dIkRm', 'fiezS', 'Si#', '*8Y', 'Vuy', '6aq', 'tWS', 'z3f', 'a6S', 'MF3', 'gBH', '7@7', 'bey', 'hxb', 'kag', 'fsI', 'pJ5', 'yT1', 'q2c', 'EgY', 'lFU', 'qeC', 'Qsj', '7G2', 'woK', 'Fq4', 'yAQ', 'Y9E', 'vD6', 'fTX', 'wUU', 'o5v', 'yc9ISgR4e7', 'rGTppxKCS6', 'Ntf1VTACml', 'YITX1aoQqK', 'uRJZcqVakQ', 'E8jt0fAcWp', 'nD3BNIXFkQ', 'yrGIC8gPGc', 'dkzb6LLhna', 'RUQ6HJfbco', 'A6DdtouM6M', 'ItzZUNkJao', '1EV67iUlKe', 'TgfOTUa6ty', 'NKmnlDPg7f', 'XoEpnjSku3', 'nggsHSmfwP', 'PvO7IBXjDz', 'U4jDv2MCmj', 'lWht8M1E5o', 'LcEv9kq3Tvloy', '0Zttxi8W0mRUw', 'xSAR
# ...

# %% [markdown]
# Test Case 5 :

# %%
# Out:
# Enter the String: ('PRTJE Q6QGK 0oSc2 O32DK wrBgf 4Ip1L SvTHi jK4ke Kpy6B qZwAV GU3P4 nNPEh cLcsK g46hI IoZHZ n53IN 8RY1z QIIuK R1yxO aAObF D3nSe pQm8U Tzdxd ue6cn ctwc4 7LAn5 L594W LshmW Dh7gt uT1SJ EsKLa YARmL T5rHI n5Nob cBD3t 0SqEx Pt6Ms vptY4 LgXvz MxvfO K3kJ8 7kczL 85UFE JgsXe Sg7sD EbPWo GFg6g mVyrW bvhTv JxEYB MRRNQem2QM YP6oYbWkmj XJabEIfxvT 8KWVbEdMTE iwOhQgWrE2 hwpkWr3SiV L2W2CGXSgo XlDO68gS05 xN3E3fyGEY qcJp25njJO JCEoxZfjvs 2D6dpbtQ2j w5oB8vrLpl TSNCU8cpzl FuOI7dto3V Dgs7sHHkRa qUGkt82mUv BWEVcEm3WI RKOC0Zoj0L ZDYchL7qih bVzCuWFnTu wTkdIAuZU2 6EAXeCjQDp mCPIBwZE8E K9r6t8vNVi qFJHkB4dbG WDEtZDUmyF F32pZG7js8 Ry74KLyWsZ vbDgqGffxG YjyEefujud Zz8kbnOhh5 jk02JUlIW7 61CoQ8iiwO gnpWN9NRbe Ila7xi5OZD oIPinYUvzC qMs15ya33S h6Jl8QVF1E cX2fX3VL6d pHdJogpwSQ gxV6AtOSpb OP5bHdp2Nt 3ABsUIEpmK Hms1ly5Gxy pU4PV6aZJ5 TvWz1IiF8M 3LMezsHI6y 8MwwEIK3Bf zwgqeAlsdG k2vFdNlHeLeFIIi lvjEmi9YUwGOqQl ob4mCNCPOuDDNrk x1eIqJkAR42tcPq jHm4Vxtux8P9YrU qKam4DT0Zdkw9A2 pY5ZwVqfElWYllj 8sclqSgewvI1ys6 
# ...
